# %% [markdown]
# # Data preparation for experiment

# %%
# external imports
import pandas as pd
import ipinfo

# %%
# internal imports
from src.utils.common_functions import (
    json_file_to_dict,
    dict_to_json_file,
    check_ip,
)
from src.utils.constants import (
    KEYS_FILEPATH,
    TRAFFIC_LOGS_FILEPATH,
    TRAFFIC_LOGS_IP_CLASSIFIED_FILEPATH,
    ANYCAST_IP_CLASSIFICATION_FILEPATH,
    ANYCAST_PII_TRAFFIC_LOGS_FILEPATH
)

# %% [markdown]
# Extract the data and filter it to get only the necessary things for experiment

# %%
# Extract raw data
traffic_logs_df = pd.read_csv(TRAFFIC_LOGS_FILEPATH)

# %% [markdown]
# Change the structure of data to be handled easier in the experiment

# %%
traffic_logs_df["ip_anycast"] = False

# %% [markdown]
# Make the necessary requests to work only with anycast ips

# %%
def classify_ip_directions(ip_to_check_list: list, file_to_save: str, use_cache: bool):
    if use_cache:
        try:
            ip_results_dict = json_file_to_dict(file_to_save)
            ip_already_check_set = set(ip_results_dict.keys())
        except:
            ip_results_dict = {}
            ip_already_check_set = set()
    else:
        ip_results_dict = {}
        ip_already_check_set = set()
    
    ips_checked = 0
    for ip_to_check in ip_to_check_list:
        if ips_checked % 100 == 0:
            print(f"Already check {ips_checked} number of IPs")
        
        ip_to_check = str(ip_to_check)
        #print(ip_to_check)
        if ip_to_check in ip_already_check_set:
            print("IP already checked")
            ips_checked += 1
            continue
        elif not check_ip(ip_to_check):
            print("IP not valid")
            ips_checked += 1
            continue

        access_token = json_file_to_dict(KEYS_FILEPATH)["ipinfo_token"]
        handler = ipinfo.getHandler(access_token)
        details = handler.getDetails(ip_to_check)
        #print(json.dumps(details.all, indent=4))
        
        try:
            ip_results_dict[ip_to_check] = details.anycast
        except:
            ip_results_dict[ip_to_check] = False

        dict_to_json_file(
            dict=ip_results_dict,
            file_path=file_to_save
        )
        
        ips_checked += 1

# %%
ips_list = traffic_logs_df["ip_dest"].unique().tolist()
print(f"Number of IPs to check anycast: {len(ips_list)}")
# Out:
# Number of IPs to check anycast: 5647

# %%
classify_ip_directions(
    ip_to_check_list=ips_list,
    file_to_save=ANYCAST_IP_CLASSIFICATION_FILEPATH,
    use_cache=True,
)
# Out:
# Already check 0 number of IPs
# IP not valid
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 100 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 200 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 300 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 400 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 500 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 600 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 700 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 800 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 900 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1000 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1100 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1200 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1300 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1400 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1500 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1600 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1700 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1800 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 1900 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 2000 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 2100 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 2200 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 2300 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 2400 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# ...
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 4900 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5000 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5100 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5200 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5300 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5400 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5500 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# Already check 5600 number of IPs
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked
# IP already checked

# %% [markdown]
# Include anycast classification in the dataset

# %%
ips_classified = json_file_to_dict(ANYCAST_IP_CLASSIFICATION_FILEPATH)

for ip_classified in ips_classified.keys():
    traffic_logs_df.loc[traffic_logs_df["ip_dest"] == ip_classified, "ip_anycast"] = ips_classified[ip_classified]

# %% [markdown]
# The experiment is only going to be carried using anycast IP that treat personal data, so we filter the unicast and the ones that do not carry personal data

# %%
# SAve the traffic log with the classification
traffic_logs_df.to_csv(TRAFFIC_LOGS_IP_CLASSIFIED_FILEPATH, sep=",", index=False)

# Create new traffic logs dataset filtering the non anycast and with non PII
anycast_pii_traffic_logs_df = traffic_logs_df.loc[
    (traffic_logs_df["ip_anycast"] == True) &
    (traffic_logs_df["PII"] != "No-PII") &
    (traffic_logs_df["PII"].notna())
]
anycast_pii_traffic_logs_df.to_csv(ANYCAST_PII_TRAFFIC_LOGS_FILEPATH, sep=",", index=False)

ips_anycast_to_hunt = anycast_pii_traffic_logs_df['ip_dest'].unique().tolist()
print(f"Number of IPs anycast to Hunt: {len(ips_anycast_to_hunt)}")
# Out:
# Number of IPs anycast to Hunt: 200
